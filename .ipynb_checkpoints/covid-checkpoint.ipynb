# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
confirmed_global = pd.read_csv('time_series_covid19_confirmed_global.csv')
deaths_global = pd.read_csv('time_series_covid19_deaths_global.csv')
recovered_global = pd.read_csv('time_series_covid19_recovered_global.csv')

# %%
# us = confirmed_global[confirmed_global['Country/Region'] == 'US']
# us = us.drop(['Province/State', 'Lat', 'Long', 'Country/Region'], axis = 1)
# us = us.reset_index(drop=True).T
# us.columns = ['cases']
# us.index.names =['Date']
# us['Date'] = us.index
# us.index = range(len(us))
# us.plot(x='Date', y='cases')

# %%
# US = confirmed_global[confirmed_global['Country/Region'] == 'US' ]
# US = US.drop(['Province/State', 'Lat', 'Long'], axis = 1)
# US = US.reset_index(drop=True).T
# US.columns = US.iloc[0]
# US.drop(['Country/Region'], inplace=True)
# US.columns.name = None
# US.columns = ['cases']
# US.index = pd.to_datetime(US.index)
# US.index = US.index.year + (US.index.dayofyear - 1)/366#I dont know how this worked but i needed to covert timestamp to decimal date
# US = US.apply(pd.to_numeric)
# #US = US['cases']
# #US.index.name = 'decimal date'
# US

# %%
df = confirmed_global[confirmed_global['Country/Region'] == 'US' ]
df = df.drop(['Province/State', 'Lat', 'Long'], axis = 1)
df = df.reset_index(drop=True).T
df.columns = df.iloc[0]
df.drop(['Country/Region'], inplace=True)
df.columns.name = None
df.columns = ['cases']
df.index = pd.to_datetime(df.index)
df.index = df.index.year + (df.index.dayofyear - 1)/366#I dont know how this worked but i needed to covert timestamp to decimal date
df = df.apply(pd.to_numeric)
#df = US['cases']
df.index.name = 'decimal date'
#df.cases = np.log(df.cases)

# %%
from sklearn.base import BaseEstimator, TransformerMixin

class IndexSelector(BaseEstimator, TransformerMixin):
    def __init__(self):
        """Return indices of a data frame for use in other estimators."""
        pass
    
    def fit(self, df, y=None):
        return self
    
    def transform(self, df):
        indices = df.index
        return indices.values.reshape(-1, 1)

# %%
def ts_train_test_split(df, cutoff, target):
    """Perform a train/test split on a data frame based on a cutoff date."""
    
    ind = df.index < cutoff
    
    df_train = df.loc[ind]
    df_test = df.loc[~ind]
    y_train = df.loc[ind, target]
    y_test = df.loc[~ind, target]
    
    return df_train, df_test, y_train, y_test

def plot_results(df, y_pred):
    """Plot predicted results and residuals."""
    
    US.plot();
    plt.plot(list(df.index), y_pred, '-r');
    plt.xlabel('date')
    plt.ylabel('Covid cases')
    plt.legend(['true', 'predicted']);
    plt.show();

    plt.plot(resd)
    plt.xlabel('date')
    plt.ylabel('residual')

# %%
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import PolynomialFeatures

# perform train/test split
cutoff = 2020.379781 
df_train, df_test, y_train, y_test = ts_train_test_split(df, cutoff, 'cases')

# construct and train pipeline
time = IndexSelector()
poly = PolynomialFeatures(degree=2)
lr = LinearRegression()
pipe = Pipeline([('indices', time),
                 ('drift', poly),
                 ('regressor', lr)])
pipe.fit(df_train, y_train)

# make predictions
y_pred = pipe.predict(df)
resd = US - y_pred
print("Test set R^2: {:g}".format(pipe.score(df_test, y_test)))
plot_results(df, y_pred)
# Out:
# Test set R^2: -6.90522

# %%
from scipy import fftpack

# %%
Y = fftpack.fft(resd-resd.mean())
#t_span = US.index[-1] - US.index[0]
f = np.linspace(0, len(Y), len(Y))#/t_span

plt.plot(f[:len(Y)//2], np.abs(Y[:len(Y)//2])/len(Y));
plt.xlabel('frequency (1/day)')
plt.ylabel('amplitude');

# %%
plt.plot(f[:15], np.abs(Y)[:15]);
plt.xlabel('frequency (1/day)')
plt.ylabel('amplitude');

# %%
from sklearn.base import BaseEstimator, TransformerMixin

class FourierComponents(BaseEstimator, TransformerMixin):
    def __init__(self, freqs):
        """Create features based on sin(2*pi*f*t) and cos(2*pi*f*t)."""
        self.freqs = freqs
    
    def fit(self, X, y=None):
        return self
    
    def transform(self, X):
        Xt = np.zeros((X.shape[0], 2*len(self.freqs)))
        
        for i, f in enumerate(self.freqs):

            Xt[:, 2*i]= np.cos(2*np.pi*f*X).reshape(-1)
            Xt[:, 2*i + 1] = np.sin(2*np.pi*f*X).reshape(-1)
    
        return Xt

# %%
from sklearn.pipeline import FeatureUnion

# construct and train pipeline
fourier = FourierComponents([2, 4]) # annual and biannual frequencies
union = FeatureUnion([('drift', poly), ('fourier', fourier)])
baseline = Pipeline([('indices', time),
                 ('union', union),
                 ('regressor', lr)])
baseline.fit(df_train, y_train)

# make predictions
y_pred = baseline.predict(df)
resd = US - y_pred
print("Test set R^2: {:g}".format(baseline.score(df_test, y_test)))
plot_results(df, y_pred)
# Out:
# Test set R^2: -0.686853

# %%
from pandas.plotting import autocorrelation_plot

autocorrelation_plot(resd)#12
plt.xlabel('Lag (days)')
plt.xlim([0, 100]);

# %%
class ResidualFeatures(BaseEstimator, TransformerMixin):
    def __init__(self, window=100):
        """Generate features based on window statistics of past noise/residuals."""
        self.window = window
        
    def fit(self, X, y=None):
        return self
    
    def transform(self, X):
        df = pd.DataFrame()
        df['residual'] = pd.Series(X, index=X.index)
        df['prior'] = df['residual'].shift(1)#The prior value
        df['mean'] = df['residual'].rolling(window=self.window).mean()#Mean of the window
        df['diff'] = df['residual'].diff().rolling(window=self.window).mean()#Mean of the derivative of the window
        df = df.fillna(method='bfill')
        
        return df

# %%
from sklearn.metrics import r2_score

# create and train residual model
resd_train = y_train - baseline.predict(df_train)
residual_feats = ResidualFeatures(window=100)
residual_model = Pipeline([('residual_features', residual_feats), ('regressor', LinearRegression())])
residual_model.fit(resd_train.iloc[:-10], resd_train.shift(-10).dropna())

# evaluate model
resd_pred = residual_model.predict(resd) # prediction for all time steps
resd_pred = pd.Series(resd_pred, index=df.index)
#resd_pred = resd_pred.shift(0).dropna() # shift predicted values to matching time step
resd_pred_test = resd_pred.loc[resd_pred.index > 2010] # evaluate only on 2010 values
print("Residual test set R^2: {:g}".format(r2_score(resd.loc[resd.index > 2010], resd_pred_test)))
# Out:
# Residual test set R^2: -0.767762

# %%
from sklearn.base import RegressorMixin

class FullModel(BaseEstimator, RegressorMixin):
    def __init__(self, baseline, residual_model, steps=10):
        """Combine a baseline and residual model to predict any number of steps in the future."""
        
        self.baseline = baseline
        self.residual_model = residual_model
        self.steps = steps
        
    def fit(self, X, y):
        self.baseline.fit(X, y)
        resd = y - self.baseline.predict(X)
        self.residual_model.fit(resd.iloc[:-self.steps], resd.shift(-self.steps).dropna())
                
        return self
    
    def predict(self, X):
        y_b = pd.Series(self.baseline.predict(X), index=X.index)
        resd = X['cases'] - y_b
        resd_pred = pd.Series(self.residual_model.predict(resd), index=X.index)
        resd_pred = resd_pred.shift(self.steps)
        y_pred = y_b + resd_pred
        
        return y_pred
    
# construct and train full model
full_model = FullModel(baseline, residual_model, steps=10)
full_model.fit(df_train, y_train)

# make predictions
y_pred = full_model.predict(df)
resd = US - y_pred
ind = resd.index > 2020.379781 
print("Test set R^2: {:g}".format(r2_score(US.loc[ind], y_pred.loc[ind])))
plot_results(df, y_pred)
# Out:
# Test set R^2: -0.613971

# %%
from scipy.stats import norm

mu = resd.mean()
sigma = resd.std(ddof=1)
dist = norm(mu, sigma)
x = np.linspace(-2, 2, 100)
f = dist.pdf(x)

resd.hist(bins=40, density=True)
plt.plot(x, f, '-r', linewidth=2);

# %%
pd.to_datetime('1/22/20')
# Out:
# Timestamp('2020-01-22 00:00:00')

# %%
US = confirmed_global[confirmed_global['Country/Region'] == 'US' ]
US = US.drop(['Province/State', 'Lat', 'Long'], axis = 1)
US = US.reset_index(drop=True).T
US.columns = US.iloc[0]
US.drop(['Country/Region'], inplace=True)
US.columns.name = None
US.columns = ['cases']
US.index = pd.to_datetime(US.index)
US.index = US.index.year + (US.index.dayofyear - 1)/366#I dont know how this worked but i needed to covert timestamp to decimal date
US = US['cases']
US
# Out:
# 2020.057377          1
# 2020.060109          1
# 2020.062842          2
# 2020.065574          2
# 2020.068306          5
#                 ...
# 2020.420765    1851520
# 2020.423497    1872660
# 2020.426230    1897380
# 2020.428962    1920061
# 2020.431694    1942363
# Name: cases, Length: 138, dtype: object

# %%
others = confirmed_global[confirmed_global['Country/Region'] .isin (['Spain', 'US', 'Italy'])]
others = others.drop(['Province/State', 'Lat', 'Long'], axis = 1)
others = others.reset_index(drop=True).T
others.columns= others.iloc[0]
others.drop(['Country/Region'], inplace=True)
# others.index.names = ['date']
others.plot()
# us.columns = ['cases']
# us.index.names =['Date']
# us['Date'] = us.index
# us.index = range(len(us))
# us.plot.line(x='Date', y='cases')

# %%
population = pd.read_csv('population_csv.txt')
pop = pd.DataFrame(population)
pop[pop['Year'] == 2018 ]
# Out:
#                          Country Name Country Code  Year       Value
# 58                         Arab World          ARB  2018   419790588
# 117            Caribbean small states          CSS  2018     7358965
# 176    Central Europe and the Baltics          CEB  2018   102511922
# 235        Early-demographic dividend          EAR  2018  3249140605
# 294               East Asia & Pacific          EAS  2018  2328220870
# ...                               ...          ...   ...         ...
# 15202           Virgin Islands (U.S.)          VIR  2018      106977
# 15231              West Bank and Gaza          PSE  2018     4569087
# 15290                     Yemen, Rep.          YEM  2018    28498687
# 15349                          Zambia          ZMB  2018    17351822
# 15408                        Zimbabwe          ZWE  2018    14439018
#
# [262 rows x 4 columns]

# %%
columns = ['Province/State', 'Country/Region', '4/19/20']
total_recovered = pd.DataFrame(recovered_global, columns=columns)
total_deaths = pd.DataFrame(deaths_global, columns=columns)
total_confirmed = pd.DataFrame(confirmed_global, columns=columns)

# %%
rec_col_mapping = {'4/19/20' : 'Recoveries'}
dea_col_mapping = {'4/19/20' : 'Deaths'}
confir_col_mapping = {'4/19/20' : 'Confirmed'}
total_recovered = total_recovered.rename(columns=rec_col_mapping, copy=False)
total_deaths = total_deaths.rename(columns=dea_col_mapping, copy=False)
total_confirmed = total_confirmed.rename(columns=confir_col_mapping, copy=False)
total_recovered.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 252 entries, 0 to 251
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Province/State  67 non-null     object
#  1   Country/Region  252 non-null    object
#  2   Recoveries      252 non-null    int64
# dtypes: int64(1), object(2)
# memory usage: 6.0+ KB

# %%
covid_updates = pd.merge(pd.merge(total_confirmed, total_recovered), total_deaths)
#covid_updates.iloc[162]#nigeria
covid_updates.head()
# Out:
#   Province/State Country/Region  Confirmed  Recoveries  Deaths
# 0            NaN    Afghanistan        996         131      33
# 1            NaN        Albania        562         314      26
# 2            NaN        Algeria       2629        1047     375
# 3            NaN        Andorra        713         235      36
# 4            NaN         Angola         24           6       2

# %%
#all_names = pd.Series(top1000.name.unique())
#all_countries = pd.Series(covid_updates['Province/State'].dropna().unique())
#all_countries = pd.Series(covid_updates['Country/Region'].unique())
#all_countries
#covid_updates.loc[95:106]
#no_multiple_countries.loc[55:65]

# %%
no_multiple_countries = covid_updates.groupby('Country/Region', as_index=False).sum()
no_multiple_countries.head()
# Out:
#   Country/Region  Confirmed  Recoveries  Deaths
# 0    Afghanistan        996         131      33
# 1        Albania        562         314      26
# 2        Algeria       2629        1047     375
# 3        Andorra        713         235      36
# 4         Angola         24           6       2

# %%
highest_cases = no_multiple_countries.sort_values(by='Confirmed', ascending=False)
highest_cases = highest_cases.reset_index(drop=True)

# %%
#time to see a country's percentages in relation to total world wide cases
total_cases = highest_cases['Confirmed'].sum()
highest_cases['Percentage'] = (highest_cases['Confirmed'] / total_cases) * 100
columns = ['Country/Region', 'Confirmed', 'Percentage']
percentage_share = pd.DataFrame(highest_cases, columns=columns)
percentage_share[:20]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-18905b7714c8> in <module>
#       1 #time to see a country's percentages in relation to total world wide cases
# ----> 2 total_cases = highest_cases['Confirmed'].sum()
#       3 highest_cases['Percentage'] = (highest_cases['Confirmed'] / total_cases) * 100
#       4 columns = ['Country/Region', 'Confirmed', 'Percentage']
#       5 percentage_share = pd.DataFrame(highest_cases, columns=columns)
#
# NameError: name 'highest_cases' is not defined

# %%
#now to get each country's death rate
with_death_rate = no_multiple_countries
with_death_rate['Death Rate'] = (no_multiple_countries['Deaths'] / no_multiple_countries['Confirmed']) * 100
columns = ['Country/Region', 'Confirmed', 'Deaths', 'Death Rate']
with_death_rate = pd.DataFrame(with_death_rate, columns=columns).sort_values(by='Death Rate', ascending=False).reset_index(drop=True)
with_death_rate[with_death_rate['Confirmed'] > 2000].reset_index(drop=True)[:10]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-04944d38ca24> in <module>
#       1 #now to get each country's death rate
# ----> 2 with_death_rate = no_multiple_countries
#       3 with_death_rate['Death Rate'] = (no_multiple_countries['Deaths'] / no_multiple_countries['Confirmed']) * 100
#       4 columns = ['Country/Region', 'Confirmed', 'Deaths', 'Death Rate']
#       5 with_death_rate = pd.DataFrame(with_death_rate, columns=columns).sort_values(by='Death Rate', ascending=False).reset_index(drop=True)
#
# NameError: name 'no_multiple_countries' is not defined

# %%
with_death_rate[with_death_rate['Country/Region'].isin(['US', 'Russia', 'Armenia', 'Azerbaijan', 'Estonia', 'Ukraine', 'Germany'])]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-08508e99585c> in <module>
# ----> 1 with_death_rate[with_death_rate['Country/Region'].isin(['US', 'Russia', 'Armenia', 'Azerbaijan', 'Estonia', 'Ukraine', 'Germany'])]
#
# NameError: name 'with_death_rate' is not defined
