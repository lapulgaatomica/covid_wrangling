# %%
first = [{'Country': 'USA',
  'Total Cases': 1078476,
  'Total Deaths': 62535.0,
  'Total Recovered': 149686.0,
  'Active Cases': 866255,
  'Serious / Critical Cases': 18697.0,
  'Total Tests': 6213977.0,
  'population': 323947000},
 {'Country': 'Spain',
  'Total Cases': 239639,
  'Total Deaths': 24543.0,
  'Total Recovered': 137984.0,
  'Active Cases': 77112,
  'Serious / Critical Cases': 2676.0,
  'Total Tests': 1455306.0,
  'population': 46438422},
 {'Country': 'Italy',
  'Total Cases': 205463,
  'Total Deaths': 27967.0,
  'Total Recovered': 75945.0,
  'Active Cases': 101551,
  'Serious / Critical Cases': 1694.0,
  'Total Tests': 1979217.0,
  'population': 60665551},
 {'Country': 'UK',
  'Total Cases': 171253,
  'Total Deaths': 26771.0,
  'Total Recovered': None,
  'Active Cases': 144138,
  'Serious / Critical Cases': 1559.0,
  'Total Tests': 901905.0,
  'population': 65110000},
 {'Country': 'France',
  'Total Cases': 166420,
  'Total Deaths': 24087.0,
  'Total Recovered': 48228.0,
  'Active Cases': 94105,
  'Serious / Critical Cases': 4207.0,
  'Total Tests': 463662.0,
  'population': 66710000},
 {'Country': 'Germany',
  'Total Cases': 162123,
  'Total Deaths': 6518.0,
  'Total Recovered': 123500.0,
  'Active Cases': 32105,
  'Serious / Critical Cases': 2415.0,
  'Total Tests': 2547052.0,
  'population': 81770900},
 {'Country': 'Turkey',
  'Total Cases': 120204,
  'Total Deaths': 3174.0,
  'Total Recovered': 48886.0,
  'Active Cases': 68144,
  'Serious / Critical Cases': 1514.0,
  'Total Tests': 1033617.0,
  'population': 78741053},
 {'Country': 'Russia',
  'Total Cases': 106498,
  'Total Deaths': 1073.0,
  'Total Recovered': 11619.0,
  'Active Cases': 93806,
  'Serious / Critical Cases': 2300.0,
  'Total Tests': 3490000.0},
 {'Country': 'Iran',
  'Total Cases': 94640,
  'Total Deaths': 6028.0,
  'Total Recovered': 75103.0,
  'Active Cases': 13509,
  'Serious / Critical Cases': 2976.0,
  'Total Tests': 463295.0},
 {'Country': 'China',
  'Total Cases': 82862,
  'Total Deaths': 4633.0,
  'Total Recovered': 77610.0,
  'Active Cases': 619,
  'Serious / Critical Cases': 41.0,
  'Total Tests': None,
  'population': 1377422166},
 {'Country': 'Brazil',
  'Total Cases': 80246,
  'Total Deaths': 5541.0,
  'Total Recovered': 34132.0,
  'Active Cases': 40573,
  'Serious / Critical Cases': 8318.0,
  'Total Tests': 339552.0,
  'population': 206135893},
 {'Country': 'Canada',
  'Total Cases': 53013,
  'Total Deaths': 3180.0,
  'Total Recovered': 21187.0,
  'Active Cases': 28646,
  'Serious / Critical Cases': 557.0,
  'Total Tests': 779613.0,
  'population': 36155487},
 {'Country': 'Belgium',
  'Total Cases': 48519,
  'Total Deaths': 7594.0,
  'Total Recovered': 11576.0,
  'Active Cases': 29349,
  'Serious / Critical Cases': 769.0,
  'Total Tests': 237963.0,
  'population': 11319511},
 {'Country': 'Netherlands',
  'Total Cases': 39316,
  'Total Deaths': 4795.0,
  'Total Recovered': None,
  'Active Cases': 34271,
  'Serious / Critical Cases': 783.0,
  'Total Tests': 219744.0,
  'population': 17019800},
 {'Country': 'India',
  'Total Cases': 34780,
  'Total Deaths': 1151.0,
  'Total Recovered': 9068.0,
  'Active Cases': 24561,
  'Serious / Critical Cases': None,
  'Total Tests': 830201.0,
  'population': 1295210000},
 {'Country': 'Peru',
  'Total Cases': 33931,
  'Total Deaths': 943.0,
  'Total Recovered': 10037.0,
  'Active Cases': 22951,
  'Serious / Critical Cases': 623.0,
  'Total Tests': 296262.0,
  'population': 31488700},
 {'Country': 'Switzerland',
  'Total Cases': 29586,
  'Total Deaths': 1737.0,
  'Total Recovered': 23100.0,
  'Active Cases': 4749,
  'Serious / Critical Cases': 167.0,
  'Total Tests': 266200.0,
  'population': 8341600},
 {'Country': 'Portugal',
  'Total Cases': 25045,
  'Total Deaths': 989.0,
  'Total Recovered': 1519.0,
  'Active Cases': 22537,
  'Serious / Critical Cases': 172.0,
  'Total Tests': 395771.0,
  'population': 10374822},
 {'Country': 'Ecuador',
  'Total Cases': 24934,
  'Total Deaths': 900.0,
  'Total Recovered': 1558.0,
  'Active Cases': 22476,
  'Serious / Critical Cases': 146.0,
  'Total Tests': 69054.0,
  'population': 16545799},
 {'Country': 'Saudi Arabia',
  'Total Cases': 22753,
  'Total Deaths': 162.0,
  'Total Recovered': 3163.0,
  'Active Cases': 19428,
  'Serious / Critical Cases': 125.0,
  'Total Tests': 200000.0,
  'population': 32248200},
 {'Country': 'Sweden',
  'Total Cases': 21092,
  'Total Deaths': 2586.0,
  'Total Recovered': 1005.0,
  'Active Cases': 17501,
  'Serious / Critical Cases': 531.0,
  'Total Tests': 119500.0,
  'population': 9894888},
 {'Country': 'Ireland',
  'Total Cases': 20612,
  'Total Deaths': 1232.0,
  'Total Recovered': 13386.0,
  'Active Cases': 5994,
  'Serious / Critical Cases': 123.0,
  'Total Tests': 153954.0,
  'population': 6378000},
 {'Country': 'Mexico',
  'Total Cases': 17799,
  'Total Deaths': 1732.0,
  'Total Recovered': 11423.0,
  'Active Cases': 4644,
  'Serious / Critical Cases': 378.0,
  'Total Tests': 81912.0,
  'population': 122273473},
 {'Country': 'Singapore',
  'Total Cases': 16169,
  'Total Deaths': 15.0,
  'Total Recovered': 1244.0,
  'Active Cases': 14910,
  'Serious / Critical Cases': 22.0,
  'Total Tests': 143919.0,
  'population': 5535000},
 {'Country': 'Pakistan',
  'Total Cases': 16117,
  'Total Deaths': 358.0,
  'Total Recovered': 4105.0,
  'Active Cases': 11654,
  'Serious / Critical Cases': 111.0,
  'Total Tests': 174160.0,
  'population': 194125062},
 {'Country': 'Chile',
  'Total Cases': 16023,
  'Total Deaths': 227.0,
  'Total Recovered': 8580.0,
  'Active Cases': 7216,
  'Serious / Critical Cases': 392.0,
  'Total Tests': 180517.0,
  'population': 18191900},
 {'Country': 'Israel',
  'Total Cases': 15870,
  'Total Deaths': 219.0,
  'Total Recovered': 8412.0,
  'Active Cases': 7239,
  'Serious / Critical Cases': 117.0,
  'Total Tests': 364467.0,
  'population': 8527400},
 {'Country': 'Austria',
  'Total Cases': 15452,
  'Total Deaths': 584.0,
  'Total Recovered': 12907.0,
  'Active Cases': 1961,
  'Serious / Critical Cases': 128.0,
  'Total Tests': 256399.0,
  'population': 8725931},
 {'Country': 'Belarus',
  'Total Cases': 14027,
  'Total Deaths': 89.0,
  'Total Recovered': 2386.0,
  'Active Cases': 11552,
  'Serious / Critical Cases': 92.0,
  'Total Tests': 176625.0,
  'population': 9498700},
 {'Country': 'Japan',
  'Total Cases': 13965,
  'Total Deaths': 425.0,
  'Total Recovered': 2368.0,
  'Active Cases': 11172,
  'Serious / Critical Cases': 306.0,
  'Total Tests': 164255.0,
  'population': 126960000},
 {'Country': 'Qatar',
  'Total Cases': 13409,
  'Total Deaths': 10.0,
  'Total Recovered': 1372.0,
  'Active Cases': 12027,
  'Serious / Critical Cases': 72.0,
  'Total Tests': 94500.0,
  'population': 2587564},
 {'Country': 'Poland',
  'Total Cases': 12877,
  'Total Deaths': 644.0,
  'Total Recovered': 3236.0,
  'Active Cases': 8997,
  'Serious / Critical Cases': 160.0,
  'Total Tests': 338027.0,
  'population': 38437239},
 {'Country': 'UAE',
  'Total Cases': 12481,
  'Total Deaths': 105.0,
  'Total Recovered': 2429.0,
  'Active Cases': 9947,
  'Serious / Critical Cases': 1.0,
  'Total Tests': 1122000.0,
  'population': 9856000},
 {'Country': 'Romania',
  'Total Cases': 12240,
  'Total Deaths': 711.0,
  'Total Recovered': 4017.0,
  'Active Cases': 7512,
  'Serious / Critical Cases': 221.0,
  'Total Tests': 175374.0,
  'population': 19861408},
 {'Country': 'S. Korea',
  'Total Cases': 10765,
  'Total Deaths': 247.0,
  'Total Recovered': 9059.0,
  'Active Cases': 1459,
  'Serious / Critical Cases': 55.0,
  'Total Tests': 619881.0},
 {'Country': 'Ukraine',
  'Total Cases': 10406,
  'Total Deaths': 261.0,
  'Total Recovered': 1238.0,
  'Active Cases': 8907,
  'Serious / Critical Cases': 138.0,
  'Total Tests': 111859.0,
  'population': 42692393},
 {'Country': 'Indonesia',
  'Total Cases': 10118,
  'Total Deaths': 792.0,
  'Total Recovered': 1522.0,
  'Active Cases': 7804,
  'Serious / Critical Cases': None,
  'Total Tests': 94599.0,
  'population': 258705000},
 {'Country': 'Denmark',
  'Total Cases': 9158,
  'Total Deaths': 452.0,
  'Total Recovered': 6546.0,
  'Active Cases': 2160,
  'Serious / Critical Cases': 62.0,
  'Total Tests': 193165.0,
  'population': 5717014},
 {'Country': 'Serbia',
  'Total Cases': 9009,
  'Total Deaths': 179.0,
  'Total Recovered': 1343.0,
  'Active Cases': 7487,
  'Serious / Critical Cases': 71.0,
  'Total Tests': 85645.0,
  'population': 7076372},
 {'Country': 'Philippines',
  'Total Cases': 8488,
  'Total Deaths': 568.0,
  'Total Recovered': 1043.0,
  'Active Cases': 6877,
  'Serious / Critical Cases': 31.0,
  'Total Tests': 104146.0,
  'population': 103279800},
 {'Country': 'Norway',
  'Total Cases': 7738,
  'Total Deaths': 210.0,
  'Total Recovered': 32.0,
  'Active Cases': 7496,
  'Serious / Critical Cases': 37.0,
  'Total Tests': 172586.0,
  'population': 5223256},
 {'Country': 'Bangladesh',
  'Total Cases': 7667,
  'Total Deaths': 168.0,
  'Total Recovered': 160.0,
  'Active Cases': 7339,
  'Serious / Critical Cases': 1.0,
  'Total Tests': 64666.0,
  'population': 161006790},
 {'Country': 'Czechia',
  'Total Cases': 7642,
  'Total Deaths': 235.0,
  'Total Recovered': 3281.0,
  'Active Cases': 4126,
  'Serious / Critical Cases': 68.0,
  'Total Tests': 242088.0},
 {'Country': 'Dominican Republic',
  'Total Cases': 6972,
  'Total Deaths': 301.0,
  'Total Recovered': 1301.0,
  'Active Cases': 5370,
  'Serious / Critical Cases': 144.0,
  'Total Tests': 25368.0,
  'population': 10075045},
 {'Country': 'Australia',
  'Total Cases': 6753,
  'Total Deaths': 91.0,
  'Total Recovered': 5715.0,
  'Active Cases': 947,
  'Serious / Critical Cases': 34.0,
  'Total Tests': 563641.0,
  'population': 24117360},
 {'Country': 'Panama',
  'Total Cases': 6378,
  'Total Deaths': 178.0,
  'Total Recovered': 527.0,
  'Active Cases': 5673,
  'Serious / Critical Cases': 92.0,
  'Total Tests': 29837.0,
  'population': 3814672},
 {'Country': 'Colombia',
  'Total Cases': 6211,
  'Total Deaths': 278.0,
  'Total Recovered': 1411.0,
  'Active Cases': 4522,
  'Serious / Critical Cases': 118.0,
  'Total Tests': 95085.0,
  'population': 48759958},
 {'Country': 'Malaysia',
  'Total Cases': 6002,
  'Total Deaths': 102.0,
  'Total Recovered': 4171.0,
  'Active Cases': 1729,
  'Serious / Critical Cases': 40.0,
  'Total Tests': 160296.0,
  'population': 31405416},
 {'Country': 'Egypt',
  'Total Cases': 5537,
  'Total Deaths': 392.0,
  'Total Recovered': 1381.0,
  'Active Cases': 3764,
  'Serious / Critical Cases': None,
  'Total Tests': 90000.0,
  'population': 91290000},
 {'Country': 'South Africa',
  'Total Cases': 5350,
  'Total Deaths': 103.0,
  'Total Recovered': 2073.0,
  'Active Cases': 3174,
  'Serious / Critical Cases': 36.0,
  'Total Tests': 197127.0,
  'population': 55653654},
 {'Country': 'Finland',
  'Total Cases': 4995,
  'Total Deaths': 211.0,
  'Total Recovered': 3000.0,
  'Active Cases': 1784,
  'Serious / Critical Cases': 48.0,
  'Total Tests': 93900.0,
  'population': 5491817},
 {'Country': 'Morocco',
  'Total Cases': 4423,
  'Total Deaths': 170.0,
  'Total Recovered': 984.0,
  'Active Cases': 3269,
  'Serious / Critical Cases': 1.0,
  'Total Tests': 34841.0,
  'population': 33337529},
 {'Country': 'Argentina',
  'Total Cases': 4285,
  'Total Deaths': 214.0,
  'Total Recovered': 1192.0,
  'Active Cases': 2879,
  'Serious / Critical Cases': 144.0,
  'Total Tests': 56058.0,
  'population': 43590400},
 {'Country': 'Kuwait',
  'Total Cases': 4024,
  'Total Deaths': 26.0,
  'Total Recovered': 1539.0,
  'Active Cases': 2459,
  'Serious / Critical Cases': 66.0,
  'Total Tests': 179000.0,
  'population': 4183658},
 {'Country': 'Algeria',
  'Total Cases': 4006,
  'Total Deaths': 450.0,
  'Total Recovered': 1779.0,
  'Active Cases': 1777,
  'Serious / Critical Cases': 22.0,
  'Total Tests': 6500.0,
  'population': 40400000},
 {'Country': 'Moldova',
  'Total Cases': 3897,
  'Total Deaths': 116.0,
  'Total Recovered': 1182.0,
  'Active Cases': 2599,
  'Serious / Critical Cases': 237.0,
  'Total Tests': 11763.0,
  'population': 3553100},
 {'Country': 'Luxembourg',
  'Total Cases': 3784,
  'Total Deaths': 90.0,
  'Total Recovered': 3213.0,
  'Active Cases': 481,
  'Serious / Critical Cases': 23.0,
  'Total Tests': 42643.0,
  'population': 576200},
 {'Country': 'Kazakhstan',
  'Total Cases': 3402,
  'Total Deaths': 25.0,
  'Total Recovered': 866.0,
  'Active Cases': 2511,
  'Serious / Critical Cases': 41.0,
  'Total Tests': 249527.0,
  'population': 17753200},
 {'Country': 'Bahrain',
  'Total Cases': 3037,
  'Total Deaths': 8.0,
  'Total Recovered': 1495.0,
  'Active Cases': 1534,
  'Serious / Critical Cases': 1.0,
  'Total Tests': 128481.0,
  'population': 1404900},
 {'Country': 'Thailand',
  'Total Cases': 2954,
  'Total Deaths': 54.0,
  'Total Recovered': 2684.0,
  'Active Cases': 216,
  'Serious / Critical Cases': 61.0,
  'Total Tests': 178083.0,
  'population': 65327652},
 {'Country': 'Hungary',
  'Total Cases': 2775,
  'Total Deaths': 312.0,
  'Total Recovered': 581.0,
  'Active Cases': 1882,
  'Serious / Critical Cases': 54.0,
  'Total Tests': 72951.0,
  'population': 9823000},
 {'Country': 'Greece',
  'Total Cases': 2591,
  'Total Deaths': 140.0,
  'Total Recovered': 1374.0,
  'Active Cases': 1077,
  'Serious / Critical Cases': 38.0,
  'Total Tests': 75170.0,
  'population': 10858018},
 {'Country': 'Oman',
  'Total Cases': 2348,
  'Total Deaths': 11.0,
  'Total Recovered': 495.0,
  'Active Cases': 1842,
  'Serious / Critical Cases': 17.0,
  'Total Tests': 40459.0,
  'population': 4420133},
 {'Country': 'Afghanistan',
  'Total Cases': 2171,
  'Total Deaths': 64.0,
  'Total Recovered': 260.0,
  'Active Cases': 1847,
  'Serious / Critical Cases': 7.0,
  'Total Tests': 10022.0,
  'population': 27657145},
 {'Country': 'Iraq',
  'Total Cases': 2085,
  'Total Deaths': 93.0,
  'Total Recovered': 1375.0,
  'Active Cases': 617,
  'Serious / Critical Cases': None,
  'Total Tests': 92061.0,
  'population': 37883543},
 {'Country': 'Croatia',
  'Total Cases': 2076,
  'Total Deaths': 69.0,
  'Total Recovered': 1348.0,
  'Active Cases': 659,
  'Serious / Critical Cases': 20.0,
  'Total Tests': 36221.0,
  'population': 4190669},
 {'Country': 'Ghana',
  'Total Cases': 2074,
  'Total Deaths': 17.0,
  'Total Recovered': 212.0,
  'Active Cases': 1845,
  'Serious / Critical Cases': 4.0,
  'Total Tests': 113497.0,
  'population': 27670174},
 {'Country': 'Armenia',
  'Total Cases': 2066,
  'Total Deaths': 32.0,
  'Total Recovered': 929.0,
  'Active Cases': 1105,
  'Serious / Critical Cases': 10.0,
  'Total Tests': 21125.0,
  'population': 2994400},
 {'Country': 'Uzbekistan',
  'Total Cases': 2017,
  'Total Deaths': 9.0,
  'Total Recovered': 1133.0,
  'Active Cases': 875,
  'Serious / Critical Cases': 8.0,
  'Total Tests': 242536.0,
  'population': 31576400},
 {'Country': 'Cameroon',
  'Total Cases': 1832,
  'Total Deaths': 61.0,
  'Total Recovered': 934.0,
  'Active Cases': 837,
  'Serious / Critical Cases': 12.0,
  'Total Tests': None,
  'population': 22709892},
 {'Country': 'Azerbaijan',
  'Total Cases': 1804,
  'Total Deaths': 24.0,
  'Total Recovered': 1325.0,
  'Active Cases': 455,
  'Serious / Critical Cases': 17.0,
  'Total Tests': 143079.0,
  'population': 9730500},
 {'Country': 'Iceland',
  'Total Cases': 1797,
  'Total Deaths': 10.0,
  'Total Recovered': 1670.0,
  'Active Cases': 117,
  'Serious / Critical Cases': None,
  'Total Tests': 48413.0,
  'population': 334300},
 {'Country': 'Bosnia and Herzegovina',
  'Total Cases': 1757,
  'Total Deaths': 69.0,
  'Total Recovered': 727.0,
  'Active Cases': 961,
  'Serious / Critical Cases': 4.0,
  'Total Tests': 30793.0,
  'population': 3531159},
 {'Country': 'Nigeria',
  'Total Cases': 1728,
  'Total Deaths': 51.0,
  'Total Recovered': 307.0,
  'Active Cases': 1370,
  'Serious / Critical Cases': 2.0,
  'Total Tests': 13689.0,
  'population': 186988000},
 {'Country': 'Estonia',
  'Total Cases': 1689,
  'Total Deaths': 52.0,
  'Total Recovered': 249.0,
  'Active Cases': 1388,
  'Serious / Critical Cases': 9.0,
  'Total Tests': 52741.0,
  'population': 1315944},
 {'Country': 'Bulgaria',
  'Total Cases': 1506,
  'Total Deaths': 66.0,
  'Total Recovered': 266.0,
  'Active Cases': 1174,
  'Serious / Critical Cases': 40.0,
  'Total Tests': 45208.0,
  'population': 7153784},
 {'Country': 'Cuba',
  'Total Cases': 1501,
  'Total Deaths': 61.0,
  'Total Recovered': 681.0,
  'Active Cases': 759,
  'Serious / Critical Cases': 10.0,
  'Total Tests': 47347.0,
  'population': 11239004},
 {'Country': 'New Zealand',
  'Total Cases': 1476,
  'Total Deaths': 19.0,
  'Total Recovered': 1241.0,
  'Active Cases': 216,
  'Serious / Critical Cases': 1.0,
  'Total Tests': 134570.0,
  'population': 4697854},
 {'Country': 'North Macedonia',
  'Total Cases': 1465,
  'Total Deaths': 77.0,
  'Total Recovered': 738.0,
  'Active Cases': 650,
  'Serious / Critical Cases': 13.0,
  'Total Tests': 16050.0},
 {'Country': 'Slovenia',
  'Total Cases': 1429,
  'Total Deaths': 91.0,
  'Total Recovered': 233.0,
  'Active Cases': 1105,
  'Serious / Critical Cases': 22.0,
  'Total Tests': 52948.0,
  'population': 2064188},
 {'Country': 'Slovakia',
  'Total Cases': 1396,
  'Total Deaths': 23.0,
  'Total Recovered': 524.0,
  'Active Cases': 849,
  'Serious / Critical Cases': 8.0,
  'Total Tests': 85922.0,
  'population': 5426252},
 {'Country': 'Lithuania',
  'Total Cases': 1385,
  'Total Deaths': 45.0,
  'Total Recovered': 589.0,
  'Active Cases': 751,
  'Serious / Critical Cases': 17.0,
  'Total Tests': 125555.0,
  'population': 2872294},
 {'Country': 'Guinea',
  'Total Cases': 1351,
  'Total Deaths': 7.0,
  'Total Recovered': 313.0,
  'Active Cases': 1031,
  'Serious / Critical Cases': None,
  'Total Tests': None,
  'population': 12947000},
 {'Country': 'Ivory Coast',
  'Total Cases': 1238,
  'Total Deaths': 14.0,
  'Total Recovered': 557.0,
  'Active Cases': 667,
  'Serious / Critical Cases': None,
  'Total Tests': None,
  'population': 22671331},
 {'Country': 'Bolivia',
  'Total Cases': 1110,
  'Total Deaths': 59.0,
  'Total Recovered': 117.0,
  'Active Cases': 934,
  'Serious / Critical Cases': 3.0,
  'Total Tests': 5791.0,
  'population': 10985059},
 {'Country': 'Djibouti',
  'Total Cases': 1089,
  'Total Deaths': 2.0,
  'Total Recovered': 642.0,
  'Active Cases': 445,
  'Serious / Critical Cases': None,
  'Total Tests': 13422.0,
  'population': 900000},
 {'Country': 'Hong Kong',
  'Total Cases': 1038,
  'Total Deaths': 4.0,
  'Total Recovered': 846.0,
  'Active Cases': 188,
  'Serious / Critical Cases': 4.0,
  'Total Tests': 154989.0,
  'population': 7324300},
 {'Country': 'Tunisia',
  'Total Cases': 980,
  'Total Deaths': 40.0,
  'Total Recovered': 294.0,
  'Active Cases': 646,
  'Serious / Critical Cases': 20.0,
  'Total Tests': 22062.0,
  'population': 11154400},
 {'Country': 'Senegal',
  'Total Cases': 933,
  'Total Deaths': 9.0,
  'Total Recovered': 334.0,
  'Active Cases': 590,
  'Serious / Critical Cases': 1.0,
  'Total Tests': 466.0,
  'population': 14799859},
 {'Country': 'Latvia',
  'Total Cases': 858,
  'Total Deaths': 15.0,
  'Total Recovered': 348.0,
  'Active Cases': 495,
  'Serious / Critical Cases': 3.0,
  'Total Tests': 57886.0,
  'population': 1961600},
 {'Country': 'Cyprus',
  'Total Cases': 850,
  'Total Deaths': 15.0,
  'Total Recovered': 148.0,
  'Active Cases': 687,
  'Serious / Critical Cases': 15.0,
  'Total Tests': 58109.0,
  'population': 847000},
 {'Country': 'Albania',
  'Total Cases': 773,
  'Total Deaths': 31.0,
  'Total Recovered': 470.0,
  'Active Cases': 272,
  'Serious / Critical Cases': 4.0,
  'Total Tests': 8253.0,
  'population': 2886026},
 {'Country': 'Honduras',
  'Total Cases': 771,
  'Total Deaths': 71.0,
  'Total Recovered': 79.0,
  'Active Cases': 621,
  'Serious / Critical Cases': 10.0,
  'Total Tests': 3643.0,
  'population': 8576532},
 {'Country': 'Kyrgyzstan',
  'Total Cases': 746,
  'Total Deaths': 8.0,
  'Total Recovered': 462.0,
  'Active Cases': 276,
  'Serious / Critical Cases': 12.0,
  'Total Tests': 51472.0,
  'population': 6047800},
 {'Country': 'Andorra',
  'Total Cases': 745,
  'Total Deaths': 42.0,
  'Total Recovered': 468.0,
  'Active Cases': 235,
  'Serious / Critical Cases': 17.0,
  'Total Tests': 1673.0,
  'population': 78014},
 {'Country': 'Lebanon',
  'Total Cases': 725,
  'Total Deaths': 24.0,
  'Total Recovered': 150.0,
  'Active Cases': 551,
  'Serious / Critical Cases': 44.0,
  'Total Tests': 34499.0,
  'population': 5988000},
 {'Country': 'Niger',
  'Total Cases': 713,
  'Total Deaths': 32.0,
  'Total Recovered': 435.0,
  'Active Cases': 246,
  'Serious / Critical Cases': None,
  'Total Tests': 5148.0,
  'population': 20715000},
 {'Country': 'Costa Rica',
  'Total Cases': 713,
  'Total Deaths': 6.0,
  'Total Recovered': 323.0,
  'Active Cases': 384,
  'Serious / Critical Cases': 8.0,
  'Total Tests': 13117.0,
  'population': 4890379},
 {'Country': 'Diamond Princess',
  'Total Cases': 712,
  'Total Deaths': 13.0,
  'Total Recovered': 645.0,
  'Active Cases': 54,
  'Serious / Critical Cases': 4.0,
  'Total Tests': None},
 {'Country': 'Sri Lanka',
  'Total Cases': 660,
  'Total Deaths': 7.0,
  'Total Recovered': 139.0,
  'Active Cases': 514,
  'Serious / Critical Cases': 1.0,
  'Total Tests': 21157.0,
  'population': 20966000},
 {'Country': 'Burkina Faso',
  'Total Cases': 641,
  'Total Deaths': 43.0,
  'Total Recovered': 498.0,
  'Active Cases': 100,
  'Serious / Critical Cases': None,
  'Total Tests': None,
  'population': 19034397},
 {'Country': 'Uruguay',
  'Total Cases': 630,
  'Total Deaths': 15.0,
  'Total Recovered': 412.0,
  'Active Cases': 203,
  'Serious / Critical Cases': 11.0,
  'Total Tests': 19016.0,
  'population': 3480222},
 {'Country': 'Somalia',
  'Total Cases': 601,
  'Total Deaths': 28.0,
  'Total Recovered': 31.0,
  'Active Cases': 542,
  'Serious / Critical Cases': 2.0,
  'Total Tests': None,
  'population': 11079000},
 {'Country': 'Guatemala',
  'Total Cases': 585,
  'Total Deaths': 16.0,
  'Total Recovered': 65.0,
  'Active Cases': 504,
  'Serious / Critical Cases': 5.0,
  'Total Tests': 7200.0,
  'population': 16176133},
 {'Country': 'San Marino',
  'Total Cases': 569,
  'Total Deaths': 41.0,
  'Total Recovered': 78.0,
  'Active Cases': 450,
  'Serious / Critical Cases': 6.0,
  'Total Tests': 2305.0,
  'population': 33005},
 {'Country': 'Georgia',
  'Total Cases': 539,
  'Total Deaths': 6.0,
  'Total Recovered': 184.0,
  'Active Cases': 349,
  'Serious / Critical Cases': 6.0,
  'Total Tests': 14718.0,
  'population': 3720400},
 {'Country': 'Mayotte',
  'Total Cases': 539,
  'Total Deaths': 4.0,
  'Total Recovered': 235.0,
  'Active Cases': 300,
  'Serious / Critical Cases': 4.0,
  'Total Tests': 3000.0,
  'population': 226915},
 {'Country': 'Channel Islands',
  'Total Cases': 537,
  'Total Deaths': 40.0,
  'Total Recovered': 386.0,
  'Active Cases': 111,
  'Serious / Critical Cases': None,
  'Total Tests': 5342.0},
 {'Country': 'DRC',
  'Total Cases': 500,
  'Total Deaths': 31.0,
  'Total Recovered': 65.0,
  'Active Cases': 404,
  'Serious / Critical Cases': None,
  'Total Tests': None,
  'population': 85026000},
 {'Country': 'Mali',
  'Total Cases': 482,
  'Total Deaths': 25.0,
  'Total Recovered': 129.0,
  'Active Cases': 328,
  'Serious / Critical Cases': None,
  'Total Tests': 2172.0,
  'population': 18135000},
 {'Country': 'Tanzania',
  'Total Cases': 480,
  'Total Deaths': 16.0,
  'Total Recovered': 167.0,
  'Active Cases': 297,
  'Serious / Critical Cases': 7.0,
  'Total Tests': None,
  'population': 55155000},
 {'Country': 'Malta',
  'Total Cases': 465,
  'Total Deaths': 4.0,
  'Total Recovered': 351.0,
  'Active Cases': 110,
  'Serious / Critical Cases': 1.0,
  'Total Tests': 32989.0,
  'population': 425384},
 {'Country': 'Jordan',
  'Total Cases': 453,
  'Total Deaths': 8.0,
  'Total Recovered': 362.0,
  'Active Cases': 83,
  'Serious / Critical Cases': 5.0,
  'Total Tests': 63737.0,
  'population': 9531712},
 {'Country': 'Taiwan',
  'Total Cases': 429,
  'Total Deaths': 6.0,
  'Total Recovered': 322.0,
  'Active Cases': 101,
  'Serious / Critical Cases': None,
  'Total Tests': 62844.0,
  'population': 23503349},
 {'Country': 'Réunion',
  'Total Cases': 420,
  'Total Deaths': None,
  'Total Recovered': 300.0,
  'Active Cases': 120,
  'Serious / Critical Cases': 2.0,
  'Total Tests': None,
  'population': 840974},
 {'Country': 'Jamaica',
  'Total Cases': 396,
  'Total Deaths': 7.0,
  'Total Recovered': 29.0,
  'Active Cases': 360,
  'Serious / Critical Cases': 3.0,
  'Total Tests': 3993.0,
  'population': 2723246},
 {'Country': 'Kenya',
  'Total Cases': 396,
  'Total Deaths': 17.0,
  'Total Recovered': 144.0,
  'Active Cases': 235,
  'Serious / Critical Cases': 2.0,
  'Total Tests': 20268.0,
  'population': 47251000},
 {'Country': 'Maldives',
  'Total Cases': 396,
  'Total Deaths': 1.0,
  'Total Recovered': 17.0,
  'Active Cases': 378,
  'Serious / Critical Cases': 2.0,
  'Total Tests': 5296.0,
  'population': 344023},
 {'Country': 'El Salvador',
  'Total Cases': 395,
  'Total Deaths': 9.0,
  'Total Recovered': 118.0,
  'Active Cases': 268,
  'Serious / Critical Cases': 3.0,
  'Total Tests': 24057.0,
  'population': 6520675},
 {'Country': 'Sudan',
  'Total Cases': 375,
  'Total Deaths': 28.0,
  'Total Recovered': 32.0,
  'Active Cases': 315,
  'Serious / Critical Cases': None,
  'Total Tests': None,
  'population': 39598700},
 {'Country': 'Palestine',
  'Total Cases': 344,
  'Total Deaths': 2.0,
  'Total Recovered': 71.0,
  'Active Cases': 271,
  'Serious / Critical Cases': None,
  'Total Tests': 27000.0},
 {'Country': 'Mauritius',
  'Total Cases': 332,
  'Total Deaths': 10.0,
  'Total Recovered': 310.0,
  'Active Cases': 12,
  'Serious / Critical Cases': 3.0,
  'Total Tests': 16028.0,
  'population': 1262879},
 {'Country': 'Venezuela',
  'Total Cases': 331,
  'Total Deaths': 10.0,
  'Total Recovered': 142.0,
  'Active Cases': 179,
  'Serious / Critical Cases': 2.0,
  'Total Tests': 458737.0,
  'population': 31028700},
 {'Country': 'Montenegro',
  'Total Cases': 322,
  'Total Deaths': 7.0,
  'Total Recovered': 214.0,
  'Active Cases': 101,
  'Serious / Critical Cases': 2.0,
  'Total Tests': 6864.0,
  'population': 621810},
 {'Country': 'Isle of Man',
  'Total Cases': 315,
  'Total Deaths': 21.0,
  'Total Recovered': 260.0,
  'Active Cases': 34,
  'Serious / Critical Cases': 21.0,
  'Total Tests': 3117.0,
  'population': 84497},
 {'Country': 'Equatorial Guinea',
  'Total Cases': 315,
  'Total Deaths': 1.0,
  'Total Recovered': 9.0,
  'Active Cases': 305,
  'Serious / Critical Cases': None,
  'Total Tests': 854.0,
  'population': 1222442},
 {'Country': 'Gabon',
  'Total Cases': 276,
  'Total Deaths': 3.0,
  'Total Recovered': 67.0,
  'Active Cases': 206,
  'Serious / Critical Cases': 1.0,
  'Total Tests': 724.0,
  'population': 1802278},
 {'Country': 'Vietnam',
  'Total Cases': 270,
  'Total Deaths': None,
  'Total Recovered': 219.0,
  'Active Cases': 51,
  'Serious / Critical Cases': 8.0,
  'Total Tests': 261004.0},
 {'Country': 'Paraguay',
  'Total Cases': 249,
  'Total Deaths': 9.0,
  'Total Recovered': 111.0,
  'Active Cases': 129,
  'Serious / Critical Cases': 1.0,
  'Total Tests': 9454.0,
  'population': 6854536},
 {'Country': 'Rwanda',
  'Total Cases': 225,
  'Total Deaths': None,
  'Total Recovered': 98.0,
  'Active Cases': 127,
  'Serious / Critical Cases': None,
  'Total Tests': 8464.0,
  'population': 11553188},
 {'Country': 'Congo',
  'Total Cases': 220,
  'Total Deaths': 9.0,
  'Total Recovered': 19.0,
  'Active Cases': 192,
  'Serious / Critical Cases': None,
  'Total Tests': None,
  'population': 4741000},
 {'Country': 'Guinea-Bissau',
  'Total Cases': 205,
  'Total Deaths': 1.0,
  'Total Recovered': 19.0,
  'Active Cases': 185,
  'Serious / Critical Cases': None,
  'Total Tests': 1500.0,
  'population': 1547777},
 {'Country': 'Faeroe Islands',
  'Total Cases': 187,
  'Total Deaths': None,
  'Total Recovered': 184.0,
  'Active Cases': 3,
  'Serious / Critical Cases': None,
  'Total Tests': 6963.0},
 {'Country': 'Martinique',
  'Total Cases': 178,
  'Total Deaths': 14.0,
  'Total Recovered': 83.0,
  'Active Cases': 81,
  'Serious / Critical Cases': 5.0,
  'Total Tests': None,
  'population': 378243},
 {'Country': 'Guadeloupe',
  'Total Cases': 151,
  'Total Deaths': 12.0,
  'Total Recovered': 95.0,
  'Active Cases': 44,
  'Serious / Critical Cases': 11.0,
  'Total Tests': None,
  'population': 400132},
 {'Country': 'Myanmar',
  'Total Cases': 150,
  'Total Deaths': 6.0,
  'Total Recovered': 27.0,
  'Active Cases': 117,
  'Serious / Critical Cases': None,
  'Total Tests': 7718.0,
  'population': 51419420},
 {'Country': 'Gibraltar',
  'Total Cases': 144,
  'Total Deaths': None,
  'Total Recovered': 131.0,
  'Active Cases': 13,
  'Serious / Critical Cases': None,
  'Total Tests': 2626.0,
  'population': 33140},
 {'Country': 'Liberia',
  'Total Cases': 141,
  'Total Deaths': 16.0,
  'Total Recovered': 45.0,
  'Active Cases': 80,
  'Serious / Critical Cases': None,
  'Total Tests': None,
  'population': 4615000},
 {'Country': 'Brunei',
  'Total Cases': 138,
  'Total Deaths': 1.0,
  'Total Recovered': 124.0,
  'Active Cases': 13,
  'Serious / Critical Cases': 2.0,
  'Total Tests': 13580.0},
 {'Country': 'Ethiopia',
  'Total Cases': 131,
  'Total Deaths': 3.0,
  'Total Recovered': 59.0,
  'Active Cases': 69,
  'Serious / Critical Cases': None,
  'Total Tests': 17842.0,
  'population': 92206005},
 {'Country': 'Madagascar',
  'Total Cases': 128,
  'Total Deaths': None,
  'Total Recovered': 92.0,
  'Active Cases': 36,
  'Serious / Critical Cases': 1.0,
  'Total Tests': 3228.0,
  'population': 22434363},
 {'Country': 'French Guiana',
  'Total Cases': 126,
  'Total Deaths': 1.0,
  'Total Recovered': 94.0,
  'Active Cases': 31,
  'Serious / Critical Cases': 2.0,
  'Total Tests': None,
  'population': 254541},
 {'Country': 'Sierra Leone',
  'Total Cases': 124,
  'Total Deaths': 7.0,
  'Total Recovered': 21.0,
  'Active Cases': 96,
  'Serious / Critical Cases': None,
  'Total Tests': None,
  'population': 7075641},
 {'Country': 'Cambodia',
  'Total Cases': 122,
  'Total Deaths': None,
  'Total Recovered': 119.0,
  'Active Cases': 3,
  'Serious / Critical Cases': 1.0,
  'Total Tests': 11975.0,
  'population': 15626444},
 {'Country': 'Togo',
  'Total Cases': 116,
  'Total Deaths': 9.0,
  'Total Recovered': 65.0,
  'Active Cases': 42,
  'Serious / Critical Cases': None,
  'Total Tests': 6882.0,
  'population': 7143000},
 {'Country': 'Trinidad and Tobago',
  'Total Cases': 116,
  'Total Deaths': 8.0,
  'Total Recovered': 72.0,
  'Active Cases': 36,
  'Serious / Critical Cases': None,
  'Total Tests': 1683.0,
  'population': 1349667},
 {'Country': 'Cabo Verde',
  'Total Cases': 116,
  'Total Deaths': 1.0,
  'Total Recovered': 2.0,
  'Active Cases': 113,
  'Serious / Critical Cases': None,
  'Total Tests': 791.0,
  'population': 531239},
 {'Country': 'Bermuda',
  'Total Cases': 111,
  'Total Deaths': 6.0,
  'Total Recovered': 48.0,
  'Active Cases': 57,
  'Serious / Critical Cases': 10.0,
  'Total Tests': 2197.0,
  'population': 61954},
 {'Country': 'Zambia',
  'Total Cases': 106,
  'Total Deaths': 3.0,
  'Total Recovered': 55.0,
  'Active Cases': 48,
  'Serious / Critical Cases': 1.0,
  'Total Tests': 5284.0,
  'population': 15933883},
 {'Country': 'Aruba',
  'Total Cases': 100,
  'Total Deaths': 2.0,
  'Total Recovered': 79.0,
  'Active Cases': 19,
  'Serious / Critical Cases': 4.0,
  'Total Tests': 1691.0,
  'population': 107394},
 {'Country': 'Eswatini',
  'Total Cases': 100,
  'Total Deaths': 1.0,
  'Total Recovered': 12.0,
  'Active Cases': 87,
  'Serious / Critical Cases': None,
  'Total Tests': 714.0},
 {'Country': 'Monaco',
  'Total Cases': 95,
  'Total Deaths': 4.0,
  'Total Recovered': 64.0,
  'Active Cases': 27,
  'Serious / Critical Cases': 1.0,
  'Total Tests': None,
  'population': 38400},
 {'Country': 'Liechtenstein',
  'Total Cases': 82,
  'Total Deaths': 1.0,
  'Total Recovered': 55.0,
  'Active Cases': 26,
  'Serious / Critical Cases': None,
  'Total Tests': 900.0,
  'population': 37623},
 {'Country': 'Uganda',
  'Total Cases': 81,
  'Total Deaths': None,
  'Total Recovered': 52.0,
  'Active Cases': 29,
  'Serious / Critical Cases': None,
  'Total Tests': 29279.0,
  'population': 33860700},
 {'Country': 'Bahamas',
  'Total Cases': 80,
  'Total Deaths': 11.0,
  'Total Recovered': 25.0,
  'Active Cases': 44,
  'Serious / Critical Cases': 1.0,
  'Total Tests': None,
  'population': 378040},
 {'Country': 'Barbados',
  'Total Cases': 80,
  'Total Deaths': 7.0,
  'Total Recovered': 39.0,
  'Active Cases': 34,
  'Serious / Critical Cases': 4.0,
  'Total Tests': 2005.0,
  'population': 285000},
 {'Country': 'Guyana',
  'Total Cases': 78,
  'Total Deaths': 8.0,
  'Total Recovered': 18.0,
  'Active Cases': 52,
  'Serious / Critical Cases': 3.0,
  'Total Tests': 519.0,
  'population': 746900},
 {'Country': 'Haiti',
  'Total Cases': 76,
  'Total Deaths': 7.0,
  'Total Recovered': 8.0,
  'Active Cases': 61,
  'Serious / Critical Cases': None,
  'Total Tests': 776.0,
  'population': 11078033},
 {'Country': 'Mozambique',
  'Total Cases': 76,
  'Total Deaths': None,
  'Total Recovered': 12.0,
  'Active Cases': 64,
  'Serious / Critical Cases': None,
  'Total Tests': 1896.0,
  'population': 26423700},
 {'Country': 'Sint Maarten',
  'Total Cases': 75,
  'Total Deaths': 13.0,
  'Total Recovered': 33.0,
  'Active Cases': 29,
  'Serious / Critical Cases': 7.0,
  'Total Tests': 302.0,
  'population': 38247},
 {'Country': 'Cayman Islands',
  'Total Cases': 73,
  'Total Deaths': 1.0,
  'Total Recovered': 10.0,
  'Active Cases': 62,
  'Serious / Critical Cases': 3.0,
  'Total Tests': 1535.0,
  'population': 58238},
 {'Country': 'Benin',
  'Total Cases': 64,
  'Total Deaths': 1.0,
  'Total Recovered': 33.0,
  'Active Cases': 30,
  'Serious / Critical Cases': None,
  'Total Tests': None,
  'population': 10653654},
 {'Country': 'Libya',
  'Total Cases': 61,
  'Total Deaths': 3.0,
  'Total Recovered': 18.0,
  'Active Cases': 40,
  'Serious / Critical Cases': None,
  'Total Tests': 1949.0,
  'population': 6385000},
 {'Country': 'French Polynesia',
  'Total Cases': 58,
  'Total Deaths': None,
  'Total Recovered': 50.0,
  'Active Cases': 8,
  'Serious / Critical Cases': 1.0,
  'Total Tests': 2409.0,
  'population': 271800},
 {'Country': 'Nepal',
  'Total Cases': 57,
  'Total Deaths': None,
  'Total Recovered': 16.0,
  'Active Cases': 41,
  'Serious / Critical Cases': None,
  'Total Tests': 57189.0,
  'population': 28431500},
 {'Country': 'Chad',
  'Total Cases': 52,
  'Total Deaths': 2.0,
  'Total Recovered': 19.0,
  'Active Cases': 31,
  'Serious / Critical Cases': None,
  'Total Tests': None,
  'population': 14497000},
 {'Country': 'CAR',
  'Total Cases': 50,
  'Total Deaths': None,
  'Total Recovered': 10.0,
  'Active Cases': 40,
  'Serious / Critical Cases': None,
  'Total Tests': None},
 {'Country': 'Macao',
  'Total Cases': 45,
  'Total Deaths': None,
  'Total Recovered': 35.0,
  'Active Cases': 10,
  'Serious / Critical Cases': 1.0,
  'Total Tests': None,
  'population': 649100},
 {'Country': 'Syria',
  'Total Cases': 43,
  'Total Deaths': 3.0,
  'Total Recovered': 21.0,
  'Active Cases': 19,
  'Serious / Critical Cases': None,
  'Total Tests': None},
 {'Country': 'Zimbabwe',
  'Total Cases': 40,
  'Total Deaths': 4.0,
  'Total Recovered': 5.0,
  'Active Cases': 31,
  'Serious / Critical Cases': None,
  'Total Tests': 7642.0,
  'population': 14240168},
 {'Country': 'Eritrea',
  'Total Cases': 39,
  'Total Deaths': None,
  'Total Recovered': 26.0,
  'Active Cases': 13,
  'Serious / Critical Cases': None,
  'Total Tests': None,
  'population': 5352000},
 {'Country': 'Saint Martin',
  'Total Cases': 38,
  'Total Deaths': 3.0,
  'Total Recovered': 24.0,
  'Active Cases': 11,
  'Serious / Critical Cases': 3.0,
  'Total Tests': None},
 {'Country': 'Mongolia',
  'Total Cases': 38,
  'Total Deaths': None,
  'Total Recovered': 10.0,
  'Active Cases': 28,
  'Serious / Critical Cases': None,
  'Total Tests': 7455.0,
  'population': 3093100},
 {'Country': 'Malawi',
  'Total Cases': 37,
  'Total Deaths': 3.0,
  'Total Recovered': 7.0,
  'Active Cases': 27,
  'Serious / Critical Cases': 1.0,
  'Total Tests': 774.0,
  'population': 16832910},
 {'Country': 'South Sudan',
  'Total Cases': 35,
  'Total Deaths': None,
  'Total Recovered': None,
  'Active Cases': 35,
  'Serious / Critical Cases': None,
  'Total Tests': None,
  'population': 12131000},
 {'Country': 'Angola',
  'Total Cases': 27,
  'Total Deaths': 2.0,
  'Total Recovered': 7.0,
  'Active Cases': 18,
  'Serious / Critical Cases': None,
  'Total Tests': None,
  'population': 25868000},
 {'Country': 'Antigua and Barbuda',
  'Total Cases': 24,
  'Total Deaths': 3.0,
  'Total Recovered': 11.0,
  'Active Cases': 10,
  'Serious / Critical Cases': 1.0,
  'Total Tests': 113.0,
  'population': 86295},
 {'Country': 'Timor-Leste',
  'Total Cases': 24,
  'Total Deaths': None,
  'Total Recovered': 16.0,
  'Active Cases': 8,
  'Serious / Critical Cases': None,
  'Total Tests': 322.0,
  'population': 1167242},
 {'Country': 'Botswana',
  'Total Cases': 23,
  'Total Deaths': 1.0,
  'Total Recovered': 5.0,
  'Active Cases': 17,
  'Serious / Critical Cases': None,
  'Total Tests': 6548.0,
  'population': 2141206},
 {'Country': 'Grenada',
  'Total Cases': 20,
  'Total Deaths': None,
  'Total Recovered': 13.0,
  'Active Cases': 7,
  'Serious / Critical Cases': 4.0,
  'Total Tests': 1406.0,
  'population': 103328},
 {'Country': 'Laos',
  'Total Cases': 19,
  'Total Deaths': None,
  'Total Recovered': 8.0,
  'Active Cases': 11,
  'Serious / Critical Cases': None,
  'Total Tests': 1927.0,
  'population': 6492400},
 {'Country': 'Belize',
  'Total Cases': 18,
  'Total Deaths': 2.0,
  'Total Recovered': 9.0,
  'Active Cases': 7,
  'Serious / Critical Cases': 1.0,
  'Total Tests': 995.0,
  'population': 370300},
 {'Country': 'Fiji',
  'Total Cases': 18,
  'Total Deaths': None,
  'Total Recovered': 12.0,
  'Active Cases': 6,
  'Serious / Critical Cases': None,
  'Total Tests': 1007.0,
  'population': 867000},
 {'Country': 'New Caledonia',
  'Total Cases': 18,
  'Total Deaths': None,
  'Total Recovered': 17.0,
  'Active Cases': 1,
  'Serious / Critical Cases': 1.0,
  'Total Tests': 4456.0,
  'population': 268767},
 {'Country': 'Saint Lucia',
  'Total Cases': 17,
  'Total Deaths': None,
  'Total Recovered': 15.0,
  'Active Cases': 2,
  'Serious / Critical Cases': None,
  'Total Tests': 446.0,
  'population': 186000},
 {'Country': 'Curaçao',
  'Total Cases': 16,
  'Total Deaths': 1.0,
  'Total Recovered': 13.0,
  'Active Cases': 2,
  'Serious / Critical Cases': None,
  'Total Tests': 343.0,
  'population': 154843},
 {'Country': 'Dominica',
  'Total Cases': 16,
  'Total Deaths': None,
  'Total Recovered': 13.0,
  'Active Cases': 3,
  'Serious / Critical Cases': None,
  'Total Tests': 383.0,
  'population': 71293},
 {'Country': 'Namibia',
  'Total Cases': 16,
  'Total Deaths': None,
  'Total Recovered': 8.0,
  'Active Cases': 8,
  'Serious / Critical Cases': None,
  'Total Tests': 704.0,
  'population': 2324388},
 {'Country': 'St. Vincent Grenadines',
  'Total Cases': 16,
  'Total Deaths': None,
  'Total Recovered': 8.0,
  'Active Cases': 8,
  'Serious / Critical Cases': None,
  'Total Tests': 108.0},
 {'Country': 'Saint Kitts and Nevis',
  'Total Cases': 15,
  'Total Deaths': None,
  'Total Recovered': 6.0,
  'Active Cases': 9,
  'Serious / Critical Cases': None,
  'Total Tests': 293.0,
  'population': 46204},
 {'Country': 'Tajikistan',
  'Total Cases': 15,
  'Total Deaths': None,
  'Total Recovered': None,
  'Active Cases': 15,
  'Serious / Critical Cases': None,
  'Total Tests': None,
  'population': 8593600},
 {'Country': 'Sao Tome and Principe',
  'Total Cases': 14,
  'Total Deaths': None,
  'Total Recovered': 4.0,
  'Active Cases': 10,
  'Serious / Critical Cases': None,
  'Total Tests': 19.0,
  'population': 187356},
 {'Country': 'Nicaragua',
  'Total Cases': 14,
  'Total Deaths': 3.0,
  'Total Recovered': 7.0,
  'Active Cases': 4,
  'Serious / Critical Cases': None,
  'Total Tests': None,
  'population': 6262703},
 {'Country': 'Falkland Islands',
  'Total Cases': 13,
  'Total Deaths': None,
  'Total Recovered': 11.0,
  'Active Cases': 2,
  'Serious / Critical Cases': None,
  'Total Tests': 372.0,
  'population': 2563},
 {'Country': 'Turks and Caicos',
  'Total Cases': 12,
  'Total Deaths': 1.0,
  'Total Recovered': 5.0,
  'Active Cases': 6,
  'Serious / Critical Cases': None,
  'Total Tests': 83.0},
 {'Country': 'Burundi',
  'Total Cases': 11,
  'Total Deaths': 1.0,
  'Total Recovered': 4.0,
  'Active Cases': 6,
  'Serious / Critical Cases': None,
  'Total Tests': 284.0,
  'population': 10114505},
 {'Country': 'Gambia',
  'Total Cases': 11,
  'Total Deaths': 1.0,
  'Total Recovered': 8.0,
  'Active Cases': 2,
  'Serious / Critical Cases': None,
  'Total Tests': 401.0,
  'population': 1882450},
 {'Country': 'Montserrat',
  'Total Cases': 11,
  'Total Deaths': 1.0,
  'Total Recovered': 2.0,
  'Active Cases': 8,
  'Serious / Critical Cases': 1.0,
  'Total Tests': 36.0,
  'population': 4922},
 {'Country': 'Greenland',
  'Total Cases': 11,
  'Total Deaths': None,
  'Total Recovered': 11.0,
  'Active Cases': 0,
  'Serious / Critical Cases': None,
  'Total Tests': 1258.0,
  'population': 55847},
 {'Country': 'Vatican City',
  'Total Cases': 11,
  'Total Deaths': None,
  'Total Recovered': 2.0,
  'Active Cases': 9,
  'Serious / Critical Cases': None,
  'Total Tests': None},
 {'Country': 'Seychelles',
  'Total Cases': 11,
  'Total Deaths': None,
  'Total Recovered': 6.0,
  'Active Cases': 5,
  'Serious / Critical Cases': None,
  'Total Tests': None,
  'population': 91400},
 {'Country': 'Suriname',
  'Total Cases': 10,
  'Total Deaths': 1.0,
  'Total Recovered': 8.0,
  'Active Cases': 1,
  'Serious / Critical Cases': None,
  'Total Tests': 404.0,
  'population': 541638},
 {'Country': 'MS Zaandam',
  'Total Cases': 9,
  'Total Deaths': 2.0,
  'Total Recovered': None,
  'Active Cases': 7,
  'Serious / Critical Cases': None,
  'Total Tests': None},
 {'Country': 'Papua New Guinea',
  'Total Cases': 8,
  'Total Deaths': None,
  'Total Recovered': None,
  'Active Cases': 8,
  'Serious / Critical Cases': None,
  'Total Tests': 604.0,
  'population': 8083700},
 {'Country': 'Mauritania',
  'Total Cases': 8,
  'Total Deaths': 1.0,
  'Total Recovered': 6.0,
  'Active Cases': 1,
  'Serious / Critical Cases': None,
  'Total Tests': 1032.0,
  'population': 3718678},
 {'Country': 'Bhutan',
  'Total Cases': 7,
  'Total Deaths': None,
  'Total Recovered': 5.0,
  'Active Cases': 2,
  'Serious / Critical Cases': None,
  'Total Tests': 10045.0,
  'population': 775620},
 {'Country': 'Yemen',
  'Total Cases': 6,
  'Total Deaths': 2.0,
  'Total Recovered': 1.0,
  'Active Cases': 3,
  'Serious / Critical Cases': None,
  'Total Tests': 120.0,
  'population': 27478000},
 {'Country': 'British Virgin Islands',
  'Total Cases': 6,
  'Total Deaths': 1.0,
  'Total Recovered': 3.0,
  'Active Cases': 2,
  'Serious / Critical Cases': None,
  'Total Tests': None,
  'population': 28514},
 {'Country': 'St. Barth',
  'Total Cases': 6,
  'Total Deaths': None,
  'Total Recovered': 6.0,
  'Active Cases': 0,
  'Serious / Critical Cases': None,
  'Total Tests': None},
 {'Country': 'Western Sahara',
  'Total Cases': 6,
  'Total Deaths': None,
  'Total Recovered': 5.0,
  'Active Cases': 1,
  'Serious / Critical Cases': None,
  'Total Tests': None,
  'population': 510713},
 {'Country': 'Caribbean Netherlands',
  'Total Cases': 5,
  'Total Deaths': None,
  'Total Recovered': None,
  'Active Cases': 5,
  'Serious / Critical Cases': None,
  'Total Tests': 110.0},
 {'Country': 'Anguilla',
  'Total Cases': 3,
  'Total Deaths': None,
  'Total Recovered': 3.0,
  'Active Cases': 0,
  'Serious / Critical Cases': None,
  'Total Tests': None,
  'population': 13452},
 {'Country': 'Comoros',
  'Total Cases': 1,
  'Total Deaths': None,
  'Total Recovered': None,
  'Active Cases': 1,
  'Serious / Critical Cases': None,
  'Total Tests': None,
  'population': 806153},
 {'Country': 'Saint Pierre Miquelon',
  'Total Cases': 1,
  'Total Deaths': None,
  'Total Recovered': None,
  'Active Cases': 1,
  'Serious / Critical Cases': None,
  'Total Tests': None}]

# %%
from fuzzywuzzy import fuzz
fuzz.partial_ratio("Russia", "Ahvenanmaa")
# Out:
# 17

# %%
second = [{'names': ['Åland Islands', 'AX', 'Aaland', 'Aland', 'Ahvenanmaa'],
  'native name': 'Åland',
  'population': 28875},
 {'names': ['American Samoa',
   'AS',
   'Amerika Sāmoa',
   'Amelika Sāmoa',
   'Sāmoa Amelika'],
  'native name': 'American Samoa',
  'population': 57100},
 {'names': ['Antarctica'], 'native name': 'Antarctica', 'population': 1000},
 {'names': ['Bonaire, Sint Eustatius and Saba', 'BQ', 'Boneiru'],
  'native name': 'Bonaire',
  'population': 17408},
 {'names': ['Bouvet Island', 'BV', 'Bouvetøya', 'Bouvet-øya'],
  'native name': 'Bouvetøya',
  'population': 0},
 {'names': ['British Indian Ocean Territory', 'IO'],
  'native name': 'British Indian Ocean Territory',
  'population': 3000},
 {'names': ['United States Minor Outlying Islands', 'UM'],
  'native name': 'United States Minor Outlying Islands',
  'population': 300},
 {'names': ['Virgin Islands (U.S.)',
   'VI',
   'USVI',
   'American Virgin Islands',
   'U.S. Virgin Islands'],
  'native name': 'Virgin Islands of the United States',
  'population': 114743},
 {'names': ['Brunei Darussalam',
   'BN',
   'Nation of Brunei',
   ' the Abode of Peace'],
  'native name': 'Negara Brunei Darussalam',
  'population': 411900},
 {'names': ['Central African Republic',
   'CF',
   'Central African Republic',
   'République centrafricaine'],
  'native name': 'Ködörösêse tî Bêafrîka',
  'population': 4998000},
 {'names': ['Christmas Island', 'CX', 'Territory of Christmas Island'],
  'native name': 'Christmas Island',
  'population': 2072},
 {'names': ['Cocos (Keeling) Islands',
   'CC',
   'Territory of the Cocos (Keeling) Islands',
   'Keeling Islands'],
  'native name': 'Cocos (Keeling) Islands',
  'population': 550},
 {'names': ['Cook Islands', 'CK', "Kūki 'Āirani"],
  'native name': 'Cook Islands',
  'population': 18100},
 {'names': ['Czech Republic', 'CZ', 'Česká republika', 'Česko'],
  'native name': 'Česká republika',
  'population': 10558524},
 {'names': ['Faroe Islands', 'FO', 'Føroyar', 'Færøerne'],
  'native name': 'Føroyar',
  'population': 49376},
 {'names': ['French Southern Territories', 'TF'],
  'native name': 'Territoire des Terres australes et antarctiques françaises',
  'population': 140},
 {'names': ['Guam', 'GU', 'Guåhån'],
  'native name': 'Guam',
  'population': 184200},
 {'names': ['Guernsey',
   'GG',
   'Bailiwick of Guernsey',
   'Bailliage de Guernesey'],
  'native name': 'Guernsey',
  'population': 62999},
 {'names': ['Heard Island and McDonald Islands', 'HM'],
  'native name': 'Heard Island and McDonald Islands',
  'population': 0},
 {'names': ['Holy See', 'Sancta Sedes', 'Vatican', 'The Vatican'],
  'native name': 'Sancta Sedes',
  'population': 451},
 {'names': ['Iran (Islamic Republic of)',
   'IR',
   'Islamic Republic of Iran',
   'Jomhuri-ye Eslāmi-ye Irān'],
  'native name': 'ایران',
  'population': 79369900},
 {'names': ['Jersey',
   'JE',
   'Bailiwick of Jersey',
   'Bailliage de Jersey',
   'Bailliage dé Jèrri'],
  'native name': 'Jersey',
  'population': 100800},
 {'names': ['Kiribati', 'KI', 'Republic of Kiribati', 'Ribaberiki Kiribati'],
  'native name': 'Kiribati',
  'population': 113400},
 {'names': ['Lesotho', 'LS', 'Kingdom of Lesotho', 'Muso oa Lesotho'],
  'native name': 'Lesotho',
  'population': 1894194},
 {'names': ['Macedonia (the former Yugoslav Republic of)',
   'MK',
   'Republic of Macedonia',
   'Република Македонија'],
  'native name': 'Македонија',
  'population': 2058539},
 {'names': ['Marshall Islands',
   'MH',
   'Republic of the Marshall Islands',
   'Aolepān Aorōkin M̧ajeļ'],
  'native name': 'M̧ajeļ',
  'population': 54880},
 {'names': ['Micronesia (Federated States of)',
   'FM',
   'Federated States of Micronesia'],
  'native name': 'Micronesia',
  'population': 102800},
 {'names': ['Nauru',
   'NR',
   'Naoero',
   'Pleasant Island',
   'Republic of Nauru',
   'Ripublik Naoero'],
  'native name': 'Nauru',
  'population': 10084},
 {'names': ['Niue', 'NU'], 'native name': 'Niuē', 'population': 1470},
 {'names': ['Norfolk Island',
   'NF',
   'Territory of Norfolk Island',
   "Teratri of Norf'k Ailen"],
  'native name': 'Norfolk Island',
  'population': 2302},
 {'names': ["Korea (Democratic People's Republic of)",
   'KP',
   "Democratic People's Republic of Korea",
   '조선민주주의인민공화국',
   'Chosŏn Minjujuŭi Inmin Konghwaguk'],
  'native name': '북한',
  'population': 25281000},
 {'names': ['Northern Mariana Islands',
   'MP',
   'Commonwealth of the Northern Mariana Islands',
   'Sankattan Siha Na Islas Mariånas'],
  'native name': 'Northern Mariana Islands',
  'population': 56940},
 {'names': ['Palau', 'PW', 'Republic of Palau', 'Beluu er a Belau'],
  'native name': 'Palau',
  'population': 17950},
 {'names': ['Palestine, State of',
   'PS',
   'State of Palestine',
   'Dawlat Filasṭin'],
  'native name': 'فلسطين',
  'population': 4682467},
 {'names': ['Pitcairn', 'PN', 'Pitcairn Henderson Ducie and Oeno Islands'],
  'native name': 'Pitcairn Islands',
  'population': 56},
 {'names': ['Puerto Rico',
   'PR',
   'Commonwealth of Puerto Rico',
   'Estado Libre Asociado de Puerto Rico'],
  'native name': 'Puerto Rico',
  'population': 3474182},
 {'names': ['Republic of Kosovo', 'XK', 'Република Косово'],
  'native name': 'Republika e Kosovës',
  'population': 1733842},
 {'names': ['Russian Federation',
   'RU',
   'Rossiya',
   'Russian Federation',
   'Российская Федерация',
   'Rossiyskaya Federatsiya'],
  'native name': 'Россия',
  'population': 146599183},
 {'names': ['Saint Barthélemy',
   'BL',
   'St. Barthelemy',
   'Collectivity of Saint Barthélemy',
   'Collectivité de Saint-Barthélemy'],
  'native name': 'Saint-Barthélemy',
  'population': 9417},
 {'names': ['Saint Helena, Ascension and Tristan da Cunha', 'SH'],
  'native name': 'Saint Helena',
  'population': 4255},
 {'names': ['Saint Martin (French part)',
   'MF',
   'Collectivity of Saint Martin',
   'Collectivité de Saint-Martin'],
  'native name': 'Saint-Martin',
  'population': 36979},
 {'names': ['Saint Pierre and Miquelon',
   'PM',
   'Collectivité territoriale de Saint-Pierre-et-Miquelon'],
  'native name': 'Saint-Pierre-et-Miquelon',
  'population': 6069},
 {'names': ['Saint Vincent and the Grenadines', 'VC'],
  'native name': 'Saint Vincent and the Grenadines',
  'population': 109991},
 {'names': ['Samoa',
   'WS',
   'Independent State of Samoa',
   'Malo Saʻoloto Tutoʻatasi o Sāmoa'],
  'native name': 'Samoa',
  'population': 194899},
 {'names': ['Solomon Islands', 'SB'],
  'native name': 'Solomon Islands',
  'population': 642000},
 {'names': ['South Georgia and the South Sandwich Islands',
   'GS',
   'South Georgia and the South Sandwich Islands'],
  'native name': 'South Georgia',
  'population': 30},
 {'names': ['Korea (Republic of)', 'KR', 'Republic of Korea'],
  'native name': '대한민국',
  'population': 50801405},
 {'names': ['Svalbard and Jan Mayen', 'SJ', 'Svalbard and Jan Mayen Islands'],
  'native name': 'Svalbard og Jan Mayen',
  'population': 2562},
 {'names': ['Swaziland',
   'SZ',
   'weSwatini',
   'Swatini',
   'Ngwane',
   'Kingdom of Swaziland',
   'Umbuso waseSwatini'],
  'native name': 'Swaziland',
  'population': 1132657},
 {'names': ['Syrian Arab Republic',
   'SY',
   'Syrian Arab Republic',
   'Al-Jumhūrīyah Al-ʻArabīyah As-Sūrīyah'],
  'native name': 'سوريا',
  'population': 18564000},
 {'names': ['Tokelau', 'TK'], 'native name': 'Tokelau', 'population': 1411},
 {'names': ['Tonga', 'TO'], 'native name': 'Tonga', 'population': 103252},
 {'names': ['Turkmenistan', 'TM'],
  'native name': 'Türkmenistan',
  'population': 4751120},
 {'names': ['Turks and Caicos Islands', 'TC'],
  'native name': 'Turks and Caicos Islands',
  'population': 31458},
 {'names': ['Tuvalu', 'TV'], 'native name': 'Tuvalu', 'population': 10640},
 {'names': ['Vanuatu',
   'VU',
   'Republic of Vanuatu',
   'Ripablik blong Vanuatu',
   'République de Vanuatu'],
  'native name': 'Vanuatu',
  'population': 277500},
 {'names': ['Viet Nam',
   'VN',
   'Socialist Republic of Vietnam',
   'Cộng hòa Xã hội chủ nghĩa Việt Nam'],
  'native name': 'Việt Nam',
  'population': 92700000},
 {'names': ['Wallis and Futuna',
   'WF',
   'Territory of the Wallis and Futuna Islands',
   'Territoire des îles Wallis et Futuna'],
  'native name': 'Wallis et Futuna',
  'population': 11750}]

# %%
big_dict = {}

for main in first:
    if 'population' not in main:
        small_dict = {}
        for i in range(len(second)):
            for name in second[i]['names']:
                if i not in small_dict.keys():
                    small_dict[i] = {'sum' : fuzz.partial_ratio(main['Country'], name), 'count':1}
                else:
                    small_dict[i]['sum'] += fuzz.partial_ratio(main['Country'], name)
                    small_dict[i]['count'] +=1
        big_dict[main['Country']] = small_dict
big_dict
# Out:
# {'Russia': {0: {'sum': 92, 'count': 5},
#   1: {'sum': 132, 'count': 5},
#   2: {'sum': 33, 'count': 1},
#   3: {'sum': 75, 'count': 3},
#   4: {'sum': 67, 'count': 4},
#   5: {'sum': 33, 'count': 2},
#   6: {'sum': 33, 'count': 2},
#   7: {'sum': 99, 'count': 5},
#   8: {'sum': 120, 'count': 4},
#   9: {'sum': 99, 'count': 4},
#   10: {'sum': 100, 'count': 3},
#   11: {'sum': 99, 'count': 4},
#   12: {'sum': 66, 'count': 3},
#   13: {'sum': 103, 'count': 4},
#   14: {'sum': 50, 'count': 4},
#   15: {'sum': 22, 'count': 2},
#   16: {'sum': 46, 'count': 3},
#   17: {'sum': 99, 'count': 4},
#   18: {'sum': 33, 'count': 2},
#   19: {'sum': 88, 'count': 4},
#   20: {'sum': 149, 'count': 4},
#   21: {'sum': 102, 'count': 5},
#   22: {'sum': 116, 'count': 4},
#   23: {'sum': 67, 'count': 4},
#   24: {'sum': 66, 'count': 4},
#   25: {'sum': 99, 'count': 4},
#   26: {'sum': 100, 'count': 3},
#   27: {'sum': 195, 'count': 6},
#   28: {'sum': 29, 'count': 2},
#   29: {'sum': 83, 'count': 4},
# ...
